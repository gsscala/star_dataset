# %%
import os
import pandas as pd
from pre_proc_functions import *

DATA_DIR = "data_pub"
OUTPUT_FILE = "metrics_summary.h5"

mat_files = []
for root, dirs, files in os.walk(DATA_DIR):
    for file in files:
        if file.endswith(".mat"):
            mat_files.append(os.path.join(root, file))

print(f"Found {len(mat_files)} .mat files.")

all_metrics = []

for file_path in mat_files:
    try:
        print(f"Processing: {file_path}")

        # Load and preprocess the dataset
        data = process_states(file_path)

        # Calculate metrics for all status periods
        metrics = analyze_metrics_by_status_period(data)

        # Add checkup identifier (folder + file)
        metrics["checkup"] = os.path.basename(file_path).replace(".mat", "")
        metrics["subfolder"] = os.path.basename(os.path.dirname(file_path))

        all_metrics.append(metrics)

    except Exception as e:
        print(f"Error processing {file_path}: {e}")

if all_metrics:
    df_metrics = pd.concat(all_metrics, ignore_index=True)

    # Save to HDF5
    df_metrics.to_hdf(OUTPUT_FILE, key="metrics", mode="w", format="table")
    print(f"Metrics saved to {OUTPUT_FILE}")

    # Example: How to read it back later
    # df = pd.read_hdf(OUTPUT_FILE, key="metrics")

else:
    print("No metrics calculated. Please check the dataset.")

if 'df_metrics' in locals():
    display(df_metrics.head())
# Out:
# Found 4366 .mat files.
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-452_7844_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-447_7840_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-448_7841_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-455_7846_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-454_7845_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-449_7842_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-450_7843_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-458_5317_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-457_5316_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU007/BW-VTC-456_5315_CU_cyc_007_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-452_7317_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-320_2985_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-314_2988_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-449_7315_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-306_4399_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-308_4401_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-309_4432_CU_cyc_002b_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-448_7314_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-319_4565_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-310_2881_CU_cyc_002b_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-455_7319_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-447_7313_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-317_4593_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-454_7318_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-322_2987_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-309_2862_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-458_7322_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-316_4592_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-310_2863_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-311_2864_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-321_2986_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-313_2865_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-311_2882_CU_cyc_002b_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-456_7320_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-457_7321_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-450_7316_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-307_4400_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-318_4564_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-315_4591_CU_cyc_002_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU002/BW-VTC-313_2883_CU_cyc_002b_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-317_5003_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-450_7609_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-447_7606_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-448_7607_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-456_7613_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-449_7608_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-455_7612_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-454_7611_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-458_5129_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-452_7610_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU004/BW-VTC-457_5128_CU_cyc_004_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-447_7783_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-456_7790_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-452_7787_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-450_7786_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-449_7785_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-455_7789_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-448_7784_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-458_7792_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-454_7788_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU006/BW-VTC-457_7791_CU_cyc_006_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU010/BW-VTC-456_8075_CU_cyc_010_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU010/BW-VTC-447_8069_CU_cyc_010_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU010/BW-VTC-450_8071_CU_cyc_010_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU010/BW-VTC-455_8074_CU_cyc_010_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU010/BW-VTC-454_8073_CU_cyc_010_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU010/BW-VTC-452_8072_CU_cyc_010_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU010/BW-VTC-458_8076_CU_cyc_010_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU010/BW-VTC-448_8070_CU_cyc_010_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-320_3261_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-455_7065_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-447_7057_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-450_7060_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-448_7058_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-322_1857_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-314_3255_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-313_3254_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-307_1848_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-318_3259_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-453_7063_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-458_7068_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-451_7061_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-308_1849_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-306_1847_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-311_1853_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-310_1851_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-454_7064_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-309_1850_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-316_3257_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-312_1852_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-319_3260_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-321_1856_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-317_3258_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-449_7059_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-452_7062_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-456_7066_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-457_7067_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-315_3256_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU000/BW-VTC-421_3363_CU_cyc_000_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-454_7907_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-450_7905_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-447_7903_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-457_7879_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-452_7906_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-458_7880_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-448_7904_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-456_7909_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-449_7878_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU008/BW-VTC-455_7908_CU_cyc_008_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-448_7124_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-311_3438_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-455_7131_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-327_2076_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-457_7133_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-315_3441_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-326_2075_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-321_3446_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-306_3431_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-450_7126_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-316_3442_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-317_2069_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-325_2074_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-308_2070_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-322_1997_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-458_7134_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-313_3440_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-314_2068_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-309_2071_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-451_7127_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-312_3439_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-319_3444_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-449_7125_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-307_3432_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-334_3470_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-323_3448_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-456_7132_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-328_2077_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-454_7130_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-310_2067_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-453_7129_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-421_5121_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-447_7123_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-452_7128_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-324_2073_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-318_3443_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU001/BW-VTC-320_3445_CU_cyc_001_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-456_7693_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-449_7688_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-450_7689_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-448_7687_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-455_7692_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-458_5215_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-454_7691_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-457_7694_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-452_7690_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU005/BW-VTC-447_7686_CU_cyc_005_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU011/BW-VTC-455_8107_CU_cyc_011_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU011/BW-VTC-447_8102_CU_cyc_011_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU011/BW-VTC-450_8105_CU_cyc_011_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU011/BW-VTC-452_8106_CU_cyc_011_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU011/BW-VTC-456_8108_CU_cyc_011_BW-VTC-AgeVal.mat
# Processing: data_pub/CU_Dynamic/CU011/BW-VTC-454_8116_CU_cyc_011_BW-VTC-AgeVal.mat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 23
#      20 print(f"Processing: {file_path}")
#      22 # Load and preprocess the dataset
# ---> 23 data = process_states(file_path)
#      25 # Calculate metrics for all status periods
#      26 metrics = analyze_metrics_by_status_period(data)
#
# File ~/Desktop/Code/star_dataset/pre_proc_all_cells/pre_proc_functions.py:34, in process_states(path)
#      24 def process_states(path):
#      25     """
#      26     Process the battery dataset and assign operational states based on the 'Line' column.
#      27
#    (...)     32         dict: Dataset including the computed 'status' column.
#      33     """
# ---> 34     data = load_cell_data(path)
#      36     # Define operational states based on 'Line' value ranges
#      37     data["status"] = np.where(data["Line"] <= 13, "Rest", "")
#
# File ~/Desktop/Code/star_dataset/pre_proc_all_cells/pre_proc_functions.py:16, in load_cell_data(file_path)
#       6 def load_cell_data(file_path):
#       7     """
#       8     Load the battery dataset from a .mat file.
#       9
#    (...)     14         dict: Dictionary containing the dataset fields.
#      15     """
# ---> 16     data = loadmat(file_path, squeeze_me=True, struct_as_record=False)["Dataset"]
#      17     data = data.__dict__
#      18     columns = ["Time", "Line", "I", "U", "status", "T1"]
#
# File ~/Desktop/Code/star_dataset/.venv/lib/python3.12/site-packages/scipy/io/matlab/_mio.py:235, in loadmat(file_name, mdict, appendmat, spmatrix, **kwargs)
#     233 with _open_file_context(file_name, appendmat) as f:
#     234     MR, _ = mat_reader_factory(f, **kwargs)
# --> 235     matfile_dict = MR.get_variables(variable_names)
#     236 if spmatrix:
#     237     from scipy.sparse import issparse, coo_matrix
#
# File ~/Desktop/Code/star_dataset/.venv/lib/python3.12/site-packages/scipy/io/matlab/_mio5.py:333, in MatFile5Reader.get_variables(self, variable_names)
#     331     continue
#     332 try:
# --> 333     res = self.read_var_array(hdr, process)
#     334 except MatReadError as err:
#     335     warnings.warn(
#     336         f'Unreadable variable "{name}", because "{err}"',
#     337         Warning, stacklevel=2)
#
# File ~/Desktop/Code/star_dataset/.venv/lib/python3.12/site-packages/scipy/io/matlab/_mio5.py:291, in MatFile5Reader.read_var_array(self, header, process)
#     274 def read_var_array(self, header, process=True):
#     275     ''' Read array, given `header`
#     276
#     277     Parameters
#    (...)    289        `process`.
#     290     '''
# --> 291     return self._matrix_reader.array_from_header(header, process)
#
# File scipy/io/matlab/_mio5_utils.pyx:665, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File scipy/io/matlab/_mio5_utils.pyx:712, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File scipy/io/matlab/_mio5_utils.pyx:963, in scipy.io.matlab._mio5_utils.VarReader5.read_struct()
#
# File scipy/io/matlab/_mio5_utils.pyx:663, in scipy.io.matlab._mio5_utils.VarReader5.read_mi_matrix()
#
# File scipy/io/matlab/_mio5_utils.pyx:710, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File scipy/io/matlab/_mio5_utils.pyx:883, in scipy.io.matlab._mio5_utils.VarReader5.read_cells()
#
# File scipy/io/matlab/_mio5_utils.pyx:663, in scipy.io.matlab._mio5_utils.VarReader5.read_mi_matrix()
#
# File scipy/io/matlab/_mio5_utils.pyx:706, in scipy.io.matlab._mio5_utils.VarReader5.array_from_header()
#
# File scipy/io/matlab/_mio5_utils.pyx:865, in scipy.io.matlab._mio5_utils.VarReader5.read_char()
#
# KeyboardInterrupt:
